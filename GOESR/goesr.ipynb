# %%
# %matplotlib inline
import h5pyd as h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.animation as animation

# %%
f = h5py.File("/shared/NOAA/GOES/OR_ABI-L2-CMIPC-M3C16_G16_s20180010057197_e20180010059581_c20180010100025.nc", "r")

# %%
list(f)
# Out:
# ['CMI',
#  'DQF',
#  'algorithm_dynamic_input_data_container',
#  'algorithm_product_version_container',
#  'band',
#  'band_id',
#  'band_wavelength',
#  'earth_sun_distance_anomaly_in_AU',
#  'esun',
#  'geospatial_lat_lon_extent',
#  'goes_imager_projection',
#  'kappa0',
#  'max_brightness_temperature',
#  'mean_brightness_temperature',
#  'min_brightness_temperature',
#  'nominal_satellite_height',
#  'nominal_satellite_subpoint_lat',
#  'nominal_satellite_subpoint_lon',
#  'number_of_image_bounds',
#  'number_of_time_bounds',
#  'outlier_pixel_count',
#  'percent_uncorrectable_GRB_errors',
#  'percent_uncorrectable_L0_errors',
#  'planck_bc1',
#  'planck_bc2',
#  'planck_fk1',
#  'planck_fk2',
#  'processing_parm_version_container',
#  'std_dev_brightness_temperature',
#  't',
#  'time_bounds',
#  'total_number_of_points',
#  'valid_pixel_count',
#  'x',
#  'x_image',
#  'x_image_bounds',
#  'y',
#  'y_image',
#  'y_image_bounds']

# %%
cmi = f["CMI"]

# %%
cmi.shape
# Out:
# (1500, 2500)

# %%
cmi.chunks
# Out:
# (1000, 1000)

# %%
cmi.dtype
# Out:
# dtype('int16')

# %%
# %time data = cmi[...]
# Out:
# CPU times: user 24 ms, sys: 8 ms, total: 32 ms
# Wall time: 575 ms

# %%
data.min(), data.max(), data.mean()
# Out:
# (-1, 3373, 2964.6286552)

# %%
plt.figure(1, figsize=(10,10),dpi=72)
plt.imshow(data, origin="lower", vmin=2000, vmax=3000)

# %%
dqf = f["DQF"]

# %%
dqf.shape
# Out:
# (1500, 2500)

# %%
dqf.chunks
# Out:
# (1000, 2000)

# %%
dqf.dtype
# Out:
# dtype('int8')

# %%
# %time data = dqf[...]
# Out:
# CPU times: user 4 ms, sys: 12 ms, total: 16 ms
# Wall time: 614 ms

# %%
data.min(), data.max(), data.mean()
# Out:
# (-1, 0, -0.012576533333333334)

# %%
plt.figure(1, figsize=(10,10),dpi=72)
plt.imshow(data, origin="lower", vmin=-1, vmax=0)

# %%
0
